# %%
import pandas as pd
import numpy as np

full_df = pd.read_csv("../data/processed/full_df.csv", index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4449 entries, 104 to 7979
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       4449 non-null   int64
#  1   BusinessTravel            4449 non-null   object
#  2   DailyRate                 4449 non-null   int64
#  3   Department                4449 non-null   object
#  4   DistanceFromHome          4449 non-null   int64
#  5   Education                 4449 non-null   float64
#  6   EducationField            4449 non-null   object
#  7   EnvironmentSatisfaction   4449 non-null   float64
#  8   Gender                    4449 non-null   object
#  9   HourlyRate                4449 non-null   int64
#  10  JobInvolvement            4449 non-null   float64
#  11  JobLevel                  4449 non-null   float64
#  12  JobRole                   4449 non-null   object
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.013679         -0.014793   0.205525
# DailyRate                 0.013679   1.000000         -0.001359  -0.006985
# DistanceFromHome         -0.014793  -0.001359          1.000000   0.016641
# Education                 0.205525  -0.006985          0.016641   1.000000
# EnvironmentSatisfaction   0.014082   0.023780         -0.021608  -0.034617
# HourlyRate                0.024911   0.040703          0.019801   0.017561
# JobInvolvement            0.031068   0.043028          0.010323   0.059247
# JobLevel                  0.491267   0.006980          0.007706   0.104074
# JobSatisfaction          -0.004447   0.029500         -0.011140  -0.016301
# MonthlyIncome             0.482626   0.015991         -0.021815   0.097421
# MonthlyRate               0.014749  -0.035353          0.016613  -0.036449
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  4449.000000  4449.000000       4449.000000  4449.000000
# mean     36.729377   801.017982          9.165430     2.909867
# std       8.776683   405.605362          7.845579     1.025184
# min      18.000000   102.000000          1.000000     1.000000
# 25%      31.000000   458.000000          2.000000     2.000000
# 50%      36.000000   804.000000          8.000000     3.000000
# 75%      42.000000  1162.000000         13.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              4449.000000  4449.000000     4449.000000  4449.000000
# mean                  2.719263    65.977073        2.739492     2.053495
# std                   1.093263    20.277369        0.712660     1.102979
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dfc = df.drop(["StandardHours", "Attrition"], axis=1).corr()

plt.figure(figsize=(20,20))
sns.heatmap(dfc, annot=True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
x = df["Age"]
y = df["TotalWorkingYears"]
sns.scatterplot(x, y)
plt.show()
# Out:
# /Users/kordianpiduch/Desktop/public_projects/venv/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
