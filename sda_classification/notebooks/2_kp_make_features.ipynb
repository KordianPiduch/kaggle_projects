# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/kordianpiduch/Desktop/public_projects/project_name/notebooks/2_kp_make_features.ipynb Cell 1' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/kordianpiduch/Desktop/public_projects/project_name/notebooks/2_kp_make_features.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/kordianpiduch/Desktop/public_projects/project_name/notebooks/2_kp_make_features.ipynb#ch0000000?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/Users/kordianpiduch/Desktop/public_projects/project_name/notebooks/2_kp_make_features.ipynb#ch0000000?line=2'>3</a> from src.helping_functions import change_type
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# # Target and Features selection

# %%
df = pd.read_csv("../data/processed/full_df.csv")
df.head()
# Out:
#    EmployeeNumber  Age BusinessTravel  DailyRate              Department  \
# 0             104   30  Travel_Rarely        852  Research & Development
# 1            1638   38  Travel_Rarely        397  Research & Development
# 2             164   26  Travel_Rarely        841  Research & Development
# 3             395   28  Travel_Rarely       1117  Research & Development
# 4              53   35  Travel_Rarely        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          1  Life Sciences                        4
# 1                 2          2        Medical                        4
# 2                 6          3          Other                        3
# 3                 8          2  Life Sciences                        4
# 4                 4          2          Other                        3
#
#    Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4449 entries, 0 to 4448
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4449 non-null   int64
#  1   Age                       4449 non-null   int64
#  2   BusinessTravel            4449 non-null   object
#  3   DailyRate                 4449 non-null   int64
#  4   Department                4449 non-null   object
#  5   DistanceFromHome          4449 non-null   int64
#  6   Education                 4449 non-null   int64
#  7   EducationField            4449 non-null   object
#  8   EnvironmentSatisfaction   4449 non-null   int64
#  9   Gender                    4449 non-null   object
#  10  HourlyRate                4449 non-null   int64
#  11  JobInvolvement            4449 non-null   int64
#  12  JobLevel                  4449 non-null   int64
#  13  JobRole                   4449 non-null   object
# ...

# %%
df.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     4449.000000  4449.000000  4449.000000       4449.000000
# mean      7956.865588   416.187458   801.017982      33339.433356
# std      17226.922333  1566.205147   405.605362     145352.131423
# min          1.000000    18.000000   102.000000          1.000000
# 25%       1735.000000    31.000000   458.000000          2.000000
# 50%       5902.000000    36.000000   804.000000          8.000000
# 75%       7014.000000    45.000000  1162.000000         17.000000
# max     100146.000000  9890.000000  1499.000000     999590.000000
#
#          Education  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count  4449.000000              4449.000000  4449.000000     4449.000000
# mean      2.909867                 2.719263    65.977073        2.739492
# std       1.025184                 1.093263    20.277369        0.712660
# min       1.000000                 1.000000    30.000000        1.000000
# ...

# %%
target = "Attrition"  # nan values 
features = ["DistanceFromHome", "JobSatisfaction", "NumCompaniesWorked", "MonthlyIncome", "Gender", 
    "TotalWorkingYears", "WorkLifeBalance", "YearsInCurrentRole","YearlyIncome"]

# %%
X = df[features]
y = df[target]

numAttr = X.select_dtypes(include='number').columns
catAttr = X.select_dtypes(exclude='number').columns

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

numeric_pipeline = Pipeline(
    [
        # custom estimator -> 
        ("std_scaler", StandardScaler()),
    ]
)

category_pipeline = Pipeline(
    [
        ('ohe', OneHotEncoder())
    ]
)
